# %%
import pandas as pd

path = 'C:/Users/최완우/선문대/3학년 1학기/파이썬 프로그래밍 응용/'
file = path + '2월.csv'

df = pd.read_csv(file, encoding='utf-8-sig')

print(df.head())
# Out:
#    번호                    도서명                           저자     출판사  발행년도  \
# 0   1             눈과 보이지 않는   데이브 에거스 글 ;숀 해리스 그림 ;송섬별 옮김  위즈덤하우스  2024
# 1   2            설탕 실(독서치료용)                          연소민  자이언트북스  2026
# 2   3       소란한 비밀:강은지 장편소설                        강은지 지음      창비  2026
# 3   4  어부바 앱에 접속하셨습니다(독서치료용)                          김경미    슈크림북  2026
# 4   5           럭키 펀치(독서치료용)                          이송현    다산책방  2026
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  \
# 0  9791171712359      NaN    7  NaN    843     1     0  2026-02-27
# 1  9791191824520      NaN  NaN  NaN    NaN     1     0  2026-02-27
# 2  9788936457433      NaN    4  NaN  813.7     1     0  2026-02-27
# 3  9791124223048      NaN  NaN  NaN    NaN     1     0  2026-02-27
# 4  9791130674490      NaN  NaN  NaN    NaN     1     0  2026-02-27
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...

# %%
df = pd.read_csv(file, index_col = 0)
print(df)
# Out:
# C:\Users\최완우\AppData\Local\Temp\ipykernel_3600\576446376.py:1: DtypeWarning: Columns (0: 세트 ISBN, 1: 권, 2: 도서권수) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, index_col = 0)
#                           도서명                           저자     출판사  발행년도  \
# 번호
# 1                  눈과 보이지 않는   데이브 에거스 글 ;숀 해리스 그림 ;송섬별 옮김  위즈덤하우스  2024
# 2                 설탕 실(독서치료용)                          연소민  자이언트북스  2026
# 3            소란한 비밀:강은지 장편소설                        강은지 지음      창비  2026
# 4       어부바 앱에 접속하셨습니다(독서치료용)                          김경미    슈크림북  2026
# 5                럭키 펀치(독서치료용)                          이송현    다산책방  2026
# ...                       ...                          ...     ...   ...
# 462627              음악이 있는 풍경                       김정환 지음  이론과 실천  1998
# 462628                    큰오빠                       박정근 지음   우리문학사  1998
# 462629                  뉴 웨이브                   제임스 모나코 지음     한나래  1996
# ...

# %%
df[df['대출건수'] > 500]
# Out:
#                                             도서명                 저자       출판사  \
# 번호
# 158944  사피엔스 :유인원에서 사이보그까지, 인간 역사의 대담하고 위대한 질문   유발 하라리 지음 ;조현욱 옮김       김영사
# 259730                         7년의 밤 :정유정 장편소설               정유정 저      은행나무
# 345101                             남한산성:김훈 장편소설              김훈 지음       학고재
# 386197                             냉정과 열정사이:Blu  츠지 히토나리 지음;양억관 옮김     소담출판사
# 408868                         해커스 토익:Listening       David Cho 지음  해커스어학연구소
#
#         발행년도           ISBN  세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수  \
# 번호
# 158944  2016  9788934972464      NaN  NaN  NaN   909.0    30  1941
# 259730  2011  9788956604992      NaN    0  NaN   813.6    10   795
# 345101  2007  9788956250595      NaN    0  NaN   813.6     5   524
# 386197  2003  9788973813704      NaN    0  NaN   833.6     6   541
# 408868  2005  9788990700148      NaN    1  NaN  740.77    29  1066
#
#               등록일자  Unnamed: 13
# 번호
# 158944  2016-04-22          NaN
# ...
